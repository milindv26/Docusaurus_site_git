# %%
import numpy as np
import matplotlib.pyplot as plt
import random

# Initialize an empty numpy array
y = np.array([])

# Set initial value of y
y_0 = 0
y = np.append(y,y_0)

# Number of iterations for the loop (example: 10)
n_iterations = 1000

# Loop to generate y_t values
for t in range(1, n_iterations):
    # Generate epsilon_t which takes value 1 and -1 with equal probability
    epsilon_t = random.choice([-1, 1])
    # Calculate y_t
    y_t = y[t-1] + epsilon_t
    # Append y_t to the array
    y = np.append(y, y_t)

plt.plot(np.arange(0,1000),y)
plt.title("Random Walk 1-D")
plt.show()

# %%
c = np.array([])

# Set initial value of y
c_0 = 0
c = np.append(c,c_0)
c
# Out:
# array([0.])
